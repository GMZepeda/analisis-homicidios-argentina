# %% [markdown]
# # ETL

# %%
# imports necesarios
import os
import pandas as pd

# %%
# definimos el directorio de trabajo
os.chdir(r'C:\PROYECTOS\SQL\homicidios')
os.getcwd()
# Out:
# 'C:\\PROYECTOS\\SQL\\homicidios'

# %%
df = pd.read_csv('SAT-HD-BU.csv', sep=";")
# Out:
# C:\Users\germa\AppData\Local\Temp\ipykernel_5520\640119582.py:1: DtypeWarning: Columns (11,21,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('SAT-HD-BU.csv', sep=";")

# %%
df.head()
# Out:
#    id_hecho tipo_hecho_segun_victima            tipo_persona_id tipo_persona  \
# 0     11535                 HD Varón   Víctima idRegistro 12235      Víctima
# 1     11535                 HD Varón  Imputado idRegistro 12929     Imputado
# 2     11535                 HD Varón  Imputado idRegistro 12931     Imputado
# 3     11535                 HD Varón  Imputado idRegistro 12930     Imputado
# 4     11536                 HD Varón  Imputado idRegistro 12933     Imputado
#
#    cant_inc  cant_vic federal  provincia_id provincia_nombre  departamento_id  \
# 0         3         1      No            58          Neuquén            58035
# 1         3         1      No            58          Neuquén            58035
# 2         3         1      No            58          Neuquén            58035
# 3         3         1      No            58          Neuquén            58035
# 4         2         1      No            58          Neuquén            58035
#
# ...

# %% [markdown]
# ## Conocer información básica

# %%
print('Cantidad de filas y columnas', df.shape)
print('Nombre columnas', df.columns)
# Out:
# Cantidad de filas y columnas (38126, 47)
# Nombre columnas Index(['id_hecho', 'tipo_hecho_segun_victima', 'tipo_persona_id',
#        'tipo_persona', 'cant_inc', 'cant_vic', 'federal', 'provincia_id',
#        'provincia_nombre', 'departamento_id', 'departamento_nombre',
#        'localidad_id', 'localidad_nombre', 'radio_censal', 'latitud_radio',
#        'longitud_radio', 'anio', 'mes', 'fecha_hecho', 'hora_hecho',
#        'tipo_lugar', 'tipo_lugar_otro', 'tipo_lugar_ampliado', 'clase_arma',
#        'clase_arma_otro', 'en_ocasion_otro_delito',
#        'en_ocasion_otro_delito_otro', 'motivo_origen_registro',
#        'motivo_origen_registro_otro', 'victima_sexo',
#        'victima_identidad_genero', 'victima_identidad_genero_otro',
#        'victima_tr_edad', 'victima_18_años_o_mas', 'victima_clase',
#        'victima_clase_otro', 'victima_situacion_ocupacional',
#        'victi_situacion_ocupacional_otro', 'victima_relacion_inculpado',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38126 entries, 0 to 38125
# Data columns (total 47 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id_hecho                          38126 non-null  int64
#  1   tipo_hecho_segun_victima          38126 non-null  object
#  2   tipo_persona_id                   38126 non-null  object
#  3   tipo_persona                      38126 non-null  object
#  4   cant_inc                          38126 non-null  int64
#  5   cant_vic                          38126 non-null  int64
#  6   federal                           38126 non-null  object
#  7   provincia_id                      38126 non-null  int64
#  8   provincia_nombre                  38126 non-null  object
#  9   departamento_id                   38126 non-null  int64
#  10  departamento_nombre               38126 non-null  object
# ...

# %% [markdown]
# ## Seleccionar solo las variables que voy a utilizar

# %%
# selecciona columnas que se van a usar para el análisis
# Selecciona las columnas por su nombre, incluyendo las que faltaban
columnas = [
    'id_hecho',
    'provincia_id', 
    'provincia_nombre', 
    'localidad_id', 
    'localidad_nombre', 
    'anio', 
    'mes', 
    'fecha_hecho', 
    'hora_hecho', 
    'tipo_lugar', 
    'tipo_lugar_otro', 
    'tipo_lugar_ampliado', 
    'motivo_origen_registro', 
    'motivo_origen_registro_otro', 
    'victima_sexo', 
    'victima_identidad_genero', 
    'victima_identidad_genero_otro', 
    'victima_tr_edad', 
    'victima_18_años_o_mas', 
    'inculpado_sexo', 
    'inculpado_identidad_genero', 
    'inculpado_identidad_genero_otro',
    'inculpado_tr_edad',
    'inculpado_18_años_o_mas'
]

df_nuevo = df[columnas]

# %%
df_nuevo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38126 entries, 0 to 38125
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   id_hecho                         38126 non-null  int64
#  1   provincia_id                     38126 non-null  int64
#  2   provincia_nombre                 38126 non-null  object
#  3   localidad_id                     38120 non-null  object
#  4   localidad_nombre                 38126 non-null  object
#  5   anio                             38126 non-null  int64
#  6   mes                              38126 non-null  int64
#  7   fecha_hecho                      38126 non-null  object
#  8   hora_hecho                       38126 non-null  object
#  9   tipo_lugar                       38126 non-null  object
#  10  tipo_lugar_otro                  200 non-null    object
#  11  tipo_lugar_ampliado              38126 non-null  object
# ...

# %% [markdown]
# ## Limpieza

# %%
df_nuevo.dtypes
# Out:
# id_hecho                            int64
# provincia_id                        int64
# provincia_nombre                   object
# localidad_id                       object
# localidad_nombre                   object
# anio                                int64
# mes                                 int64
# fecha_hecho                        object
# hora_hecho                         object
# tipo_lugar                         object
# tipo_lugar_otro                    object
# tipo_lugar_ampliado                object
# motivo_origen_registro             object
# motivo_origen_registro_otro        object
# victima_sexo                       object
# victima_identidad_genero           object
# victima_identidad_genero_otro      object
# victima_tr_edad                    object
# victima_18_años_o_mas              object
# inculpado_sexo                     object
# inculpado_identidad_genero         object
# inculpado_identidad_genero_otro    object
# ...

# %% [markdown]
# ### Corregir el formato de hora y fecha

# %%
# Convertir a datatime (errors='coerse' convierte errores en nulos)
df_nuevo = df_nuevo.copy()
df_nuevo['fecha_hecho'] = pd.to_datetime(df_nuevo['fecha_hecho'], format='%d/%m/%Y', errors='coerce')
df_nuevo['hora_hecho'] = pd.to_datetime(df_nuevo['hora_hecho'],format='%H:%M:%S', errors='coerce').dt.time

# %% [markdown]
# ### Detectar NaN

# %%
# buscar nulos
df_nuevo.isnull().sum()
# Out:
# provincia_id                           0
# provincia_nombre                       0
# localidad_id                           6
# localidad_nombre                       0
# anio                                   0
# mes                                    0
# fecha_hecho                            0
# hora_hecho                             0
# tipo_lugar                             0
# tipo_lugar_otro                    37926
# tipo_lugar_ampliado                    0
# motivo_origen_registro                 0
# motivo_origen_registro_otro        37989
# victima_sexo                           0
# victima_identidad_genero               0
# victima_identidad_genero_otro      17325
# victima_tr_edad                        0
# victima_18_años_o_mas                  0
# inculpado_sexo                         0
# inculpado_identidad_genero             0
# inculpado_identidad_genero_otro    24650
# dtype: int64

# %%
# tratar valores nulos y rellenar con texto
df_nuevo = df_nuevo.dropna(subset=['localidad_id']) # no es relevante la cantidad de NaN
df_nuevo['tipo_lugar_otro'] = df_nuevo['tipo_lugar_otro'].fillna('No especificado')
df_nuevo['motivo_origen_registro_otro'] = df_nuevo['motivo_origen_registro_otro'].fillna('No especificado')
df_nuevo['victima_identidad_genero_otro'] = df_nuevo['victima_identidad_genero_otro'].fillna('No especificado')
df_nuevo['inculpado_identidad_genero_otro'] = df_nuevo['inculpado_identidad_genero_otro'].fillna('No especificado')

# %% [markdown]
# ###  Limpiar y estandarizar textos

# %%
# detectar errores de escritura, categorías y desbalances
for col in df_nuevo.select_dtypes(include='object').columns:
    print(df_nuevo[col].value_counts(dropna=False))
# Out:
# provincia_nombre
# Buenos Aires                       15673
# Santa Fe                            5538
# Tucumán                             1959
# Ciudad Autónoma de Buenos Aires     1878
# Córdoba                             1815
# Mendoza                             1563
# Chaco                               1379
# Salta                               1322
# Misiones                             972
# Entre Ríos                           878
# Chubut                               652
# Corrientes                           648
# Santiago del Estero                  642
# Neuquén                              591
# Formosa                              552
# Río Negro                            457
# Jujuy                                398
# San Juan                             271
# San Luis                             241
# Santa Cruz                           227
# Catamarca                            158
# La Rioja                             134
# ...

# %% [markdown]
# #### Tratamos 'localidad_id'

# %%
# Mostrar los valores únicos de las columnas
df_nuevo['localidad_id'].unique()
# Out:
# array(['100', '40', '70', '10', '30', '130', '50', '220', '20', '200',
#        '170', '310', '60', '270', '180', '80', '230', '160', '350', '120',
#        '110', '105030', '21010', '35020', '210', '90', '21020', '999',
#        '140', '260', '150', '450', '390', '400', '250', '190', '240',
#        '360', '112020', '35010', '320', '560', '999-999-2', '280', '370',
#        '140020', '999-999-6', '290', '300', '28010', '126070', '340',
#        '70020', 170, 180, 310, 140, 270, 80, 230, 20, 160, 200, 60, 10,
#        50, 100, 30, 120, 40, 90, 70, 220, 210, 450, 190, 290, 105030, 400,
#        110, 560, 440, 130, 280, 340, 150, 370, 360, 154040, 126070, 390,
#        300, 240, 21020, 250, 140020, 77020, 126060, 260, 320, 350, 330,
#        380, 999, 550.0, 460.0, 480.0], dtype=object)

# %%
df_nuevo['localidad_id'].nunique()
# Out:
# 107

# %%
# Mostrar los valores únicos con su representación exacta
# para ver diferencias entre texto, números, espacios en blanco, etc.
#for x in df_nuevo['localidad_id'].unique():
   # print(repr(x))

# %%
# Mostrar las filas donde es igual a, para ver si la info es relevante
print(df_nuevo[df_nuevo['localidad_id'] == '999-999-2'])
print(df_nuevo[df_nuevo['localidad_id'] == '999-999-6'])
# Out:
#        id_hecho  provincia_id                 provincia_nombre localidad_id  \
# 6515      16185             2  Ciudad Autónoma de Buenos Aires    999-999-2
# 6516      16185             2  Ciudad Autónoma de Buenos Aires    999-999-2
# 15934     21996             2  Ciudad Autónoma de Buenos Aires    999-999-2
# 15935     21996             2  Ciudad Autónoma de Buenos Aires    999-999-2
#
#                localidad_nombre  anio  mes fecha_hecho hora_hecho  \
# 6515   Localidad sin determinar  2018   11  2018-11-16   21:45:00
# 6516   Localidad sin determinar  2018   11  2018-11-16   21:45:00
# 15934  Localidad sin determinar  2020    8  2020-08-15   06:15:00
# 15935  Localidad sin determinar  2020    8  2020-08-15   06:15:00
#
#         tipo_lugar  ...    victima_sexo victima_identidad_genero  \
# 6515   Vía pública  ...  No corresponde           No corresponde
# 6516   Vía pública  ...       Masculino                    Varón
# ...

# %% [markdown]
# Se detectaron códigos especiales (999-999-2 y 999-999-6) cuyo contenido en 'localidad_nombre'
# es 'Localidad sin determinar'.
# Como el análisis busca mostrar cuáles son las tres provincias y localidades
# donde se han detectado la mayor cantidad de homicidios,
# se decide reemplazar dichos valores por nulos.

# %%
# Reemplazar los códigos de "Localidad sin determinar" por valores nulos (NaN)
df_nuevo['localidad_id'] = df_nuevo['localidad_id'].replace(['999-999-2', '999-999-6'], pd.NA)

# %%
# Convertir la columna a tipo numérico (los valores no convertibles quedan como NaN)
df_nuevo['localidad_id'] = pd.to_numeric(df_nuevo['localidad_id'], errors='coerce').astype('Int64')

# %%
# Verificar que la conversión se realizó correctamente
df_nuevo['localidad_id'].dtype
# Out:
# Int64Dtype()

# %%
df_nuevo['localidad_id'].unique()
# Out:
# <IntegerArray>
# [   100,     40,     70,     10,     30,    130,     50,    220,     20,
#     200,    170,    310,     60,    270,    180,     80,    230,    160,
#     350,    120,    110, 105030,  21010,  35020,    210,     90,  21020,
#     999,    140,    260,    150,    450,    390,    400,    250,    190,
#     240,    360, 112020,  35010,    320,    560,   <NA>,    280,    370,
#  140020,    290,    300,  28010, 126070,    340,  70020,    440, 154040,
#   77020, 126060,    330,    380,    550,    460,    480]
# Length: 61, dtype: Int64

# %%
df_nuevo['localidad_id'].nunique()
# Out:
# 60

# %% [markdown]
# ### Tratamos 'hora_hecho'

# %%
df_nuevo['hora_hecho'].value_counts()
# Out:
# hora_hecho
# 11:11:11    15413
# 11:11:00      878
# 00:00:00      605
# 22:00:00      454
# 21:00:00      423
#             ...
# 07:58:00        2
# 07:02:00        2
# 12:17:00        2
# 05:34:00        2
# 09:59:00        2
# Name: count, Length: 1100, dtype: int64

# %%
from datetime import time
df_nuevo[df_nuevo['hora_hecho'] == time(11,11,11)]
# Out:
#        id_hecho  provincia_id provincia_nombre  localidad_id  \
# 772       12038            82         Santa Fe           270
# 773       12038            82         Santa Fe           270
# 1836      12710            82         Santa Fe           270
# 1837      12710            82         Santa Fe           270
# 2221      12955            62        Río Negro            90
# ...         ...           ...              ...           ...
# 38109     37746             6     Buenos Aires            10
# 38110     37746             6     Buenos Aires            10
# 38111     37746             6     Buenos Aires            10
# 38112     37747             6     Buenos Aires            10
# 38113     37747             6     Buenos Aires            10
#
#        localidad_nombre  anio  mes fecha_hecho hora_hecho  \
# 772             Rosario  2017    8  2017-08-31   11:11:11
# 773             Rosario  2017    8  2017-08-31   11:11:11
# ...

# %%
df_nuevo[df_nuevo['hora_hecho'] == time(11,11,00)]
# Out:
#        id_hecho  provincia_id                 provincia_nombre  localidad_id  \
# 29817     30728            58                          Neuquén           110
# 29818     30728            58                          Neuquén           110
# 30069     30904            82                         Santa Fe           270
# 30070     30904            82                         Santa Fe           270
# 30305     31052            82                         Santa Fe           270
# ...         ...           ...                              ...           ...
# 35897     35534            14                          Córdoba            10
# 35958     35868            86              Santiago del Estero           110
# 35959     35868            86              Santiago del Estero           110
# 36009     35910             2  Ciudad Autónoma de Buenos Aires            10
# 36010     35910             2  Ciudad Autónoma de Buenos Aires            10
#
# ...

# %% [markdown]
# Se conservan los datos con horas '11:11:11' y '11:11:00' ya que representan una gran cantidad de registros necesarios para el análisis. Sin embargo a la hora de analizar la hora del suceso, se procederá a tomar dicha hora dentro de una franja horaria más amplia para evitar el impacto que estos valores puedan tener sobre los resultados.

# %% [markdown]
# ### Tratamos 'victima_18_años_o_mas'

# %%
# ver los valores únicos y las veces que aparecen
df_nuevo['victima_18_años_o_mas'].value_counts(dropna=False)
# Out:
# victima_18_años_o_mas
# No corresponde    20798
# Sí                13939
# Si                 1665
# No                 1391
# Sin determinar      327
# Name: count, dtype: int64

# %%
# renombramos la columna
df_nuevo = df_nuevo.rename(columns={'victima_18_años_o_mas':'victima_18_anios_o_mas'})

# %%
# unificamos la categoría 'Si' para evitar duplicados
df_nuevo['victima_18_anios_o_mas'] = df_nuevo['victima_18_anios_o_mas'].replace('Sí','Si')

# %%
df_nuevo['victima_18_anios_o_mas'] = df_nuevo['victima_18_anios_o_mas'].replace('No corresponde', 'Sin determinar')

# %%
df_nuevo['victima_18_anios_o_mas'].value_counts()
# Out:
# victima_18_anios_o_mas
# Sin determinar    21125
# Si                15604
# No                 1391
# Name: count, dtype: int64

# %% [markdown]
# ### Tratamos 'victima_identidad_genero_otro'

# %%
df_nuevo['victima_identidad_genero_otro'].value_counts(dropna=False)
# Out:
# victima_identidad_genero_otro
# No especificado    17322
# -----------        16079
# No corresponde      4719
# Name: count, dtype: int64

# %%
df_nuevo['victima_identidad_genero_otro'] = df_nuevo['victima_identidad_genero_otro'].replace(
    '-----------','No especificado')

# %%
df_nuevo['victima_identidad_genero_otro'].value_counts()
# Out:
# victima_identidad_genero_otro
# No especificado    33401
# No corresponde      4719
# Name: count, dtype: int64

# %% [markdown]
# ### Tratamos ''inculpado_identidad_genero_otro'

# %%
df_nuevo['inculpado_identidad_genero_otro'].value_counts(dropna=False)
# Out:
# inculpado_identidad_genero_otro
# No especificado    24644
# -------            13473
# Sin determinar         3
# Name: count, dtype: int64

# %%
df_nuevo['inculpado_identidad_genero_otro'] = df_nuevo['inculpado_identidad_genero_otro'].replace(
    '-------','No especificado')
df_nuevo['inculpado_identidad_genero_otro'] = df_nuevo['inculpado_identidad_genero_otro'].replace(
    'Sin determinar','No especificado')

# %%
df_nuevo['inculpado_identidad_genero_otro'].value_counts()
# Out:
# inculpado_identidad_genero_otro
# No especificado    38120
# Name: count, dtype: int64

# %% [markdown]
# ### Tratamos 'tipo_lugar_ampliado'

# %%
df_nuevo['tipo_lugar_ampliado'].value_counts(dropna=False)
# Out:
# tipo_lugar_ampliado
# Vía pública                                            20587
# Domicilio particular                                   11102
# Sin determinar                                          3180
# Comercio                                                 839
# Interior de rodados                                      597
# Campo/descampado/zona rural                              436
# Cárcel o comisaría                                       342
# Establecimiento zona rural                               155
# Otro lugar                                               123
# Río/canal/arroyo/mar/dique                               104
# Basural/centro de reciclaje/relleno sanitario             87
# Bar/ Boliche/Salón de fiestas/Fiesta                      80
# Canchas/club                                              76
# Establecimiento de salud                                  73
# Hotel/Motel/Hospedaje temporario                          53
# ...

# %%
df_nuevo['tipo_lugar_ampliado'] = df_nuevo['tipo_lugar_ampliado'].replace(
    'Bar/ Boliche/Salón de fiestas/Fiesta','Bar/Boliche/Salón de fiestas/Fiesta')

# %%
df_nuevo['tipo_lugar_ampliado'] = df_nuevo['tipo_lugar_ampliado'].replace(
    'Casa/edificio abandonado /Obra en construcción','Casa/edificio abandonado/Obra en construcción')

# %%
df_nuevo['tipo_lugar_ampliado'].value_counts()
# Out:
# tipo_lugar_ampliado
# Vía pública                                            20587
# Domicilio particular                                   11102
# Sin determinar                                          3180
# Comercio                                                 839
# Interior de rodados                                      597
# Campo/descampado/zona rural                              436
# Cárcel o comisaría                                       342
# Establecimiento zona rural                               155
# Otro lugar                                               123
# Río/canal/arroyo/mar/dique                               104
# Bar/Boliche/Salón de fiestas/Fiesta                       94
# Basural/centro de reciclaje/relleno sanitario             87
# Canchas/club                                              76
# Establecimiento de salud                                  73
# Casa/edificio abandonado/Obra en construcción             60
# ...

# %% [markdown]
# ## Duplicados

# %%
# contar cuántos duplicados hay
df_nuevo.duplicated().sum()
# Out:
# np.int64(1591)

# %%
# ver cuáles son
df_nuevo[df_nuevo.duplicated(keep=False)].head()
# Out:
#     id_hecho  provincia_id provincia_nombre  localidad_id    localidad_nombre  \
# 1      11535            58          Neuquén           100            Plottier
# 2      11535            58          Neuquén           100            Plottier
# 3      11535            58          Neuquén           100            Plottier
# 46     11573            66            Salta            20  Colonia Santa Rosa
# 47     11573            66            Salta            20  Colonia Santa Rosa
#
#     anio  mes fecha_hecho hora_hecho            tipo_lugar  ...  \
# 1   2017    1  2017-01-14   22:38:00  Domicilio particular  ...
# 2   2017    1  2017-01-14   22:38:00  Domicilio particular  ...
# 3   2017    1  2017-01-14   22:38:00  Domicilio particular  ...
# 46  2017    1  2017-01-08   06:30:00           Vía pública  ...
# 47  2017    1  2017-01-08   06:30:00           Vía pública  ...
#
#       victima_sexo victima_identidad_genero victima_identidad_genero_otro  \
# ...

# %%
df_nuevo[df_nuevo.duplicated(keep=False)].tail()
# Out:
#        id_hecho  provincia_id provincia_nombre  localidad_id localidad_nombre  \
# 38091     37740             6     Buenos Aires            10          Quilmes
# 38092     37740             6     Buenos Aires            10          Quilmes
# 38094     37740             6     Buenos Aires            10          Quilmes
# 38097     37741             6     Buenos Aires            10          Quilmes
# 38098     37741             6     Buenos Aires            10          Quilmes
#
#        anio  mes fecha_hecho hora_hecho            tipo_lugar  ...  \
# 38091  2024    9  2024-09-20   11:11:11           Vía pública  ...
# 38092  2024    9  2024-09-20   11:11:11           Vía pública  ...
# 38094  2024    9  2024-09-20   11:11:11           Vía pública  ...
# 38097  2024    9  2024-09-28   11:11:11  Domicilio particular  ...
# 38098  2024    9  2024-09-28   11:11:11  Domicilio particular  ...
#
#          victima_sexo victima_identidad_genero victima_identidad_genero_otro  \
# ...

# %%
# eliminamos duplicados
df_nuevo = df_nuevo.drop_duplicates()

# %%
# confirmar que no queden duplicados
df_nuevo.duplicated().sum()
# Out:
# np.int64(0)

# %%
# ver el tamaño final de tabla
print('Cantidad de filas y columnas', df_nuevo.shape)
print('Nombre columnas', df_nuevo.columns)
# Out:
# Cantidad de filas y columnas (36529, 24)
# Nombre columnas Index(['id_hecho', 'provincia_id', 'provincia_nombre', 'localidad_id',
#        'localidad_nombre', 'anio', 'mes', 'fecha_hecho', 'hora_hecho',
#        'tipo_lugar', 'tipo_lugar_otro', 'tipo_lugar_ampliado',
#        'motivo_origen_registro', 'motivo_origen_registro_otro', 'victima_sexo',
#        'victima_identidad_genero', 'victima_identidad_genero_otro',
#        'victima_tr_edad', 'victima_18_anios_o_mas', 'inculpado_sexo',
#        'inculpado_identidad_genero', 'inculpado_identidad_genero_otro',
#        'inculpado_tr_edad', 'inculpado_18_años_o_mas'],
#       dtype='object')

# %% [markdown]
# ### Tratamos 'victima_tr_edad'

# %%
df_nuevo['victima_tr_edad'].value_counts()
# Out:
# victima_tr_edad
# No corresponde    19305
# 20-24              2661
# 25-29              2512
# 30-34              2333
# 15-19              1801
# 35-39              1599
# 40-44              1317
# 45-49               958
# 50-54               724
# 55-59               603
# 60-64               474
# Sin determinar      459
# 65-69               408
# 70-74               324
# 4 o menos           245
# 75-79               233
# 10-14               187
# 80-84               176
# 5-9                  88
# 85-89                82
# 90 y más             40
# Name: count, dtype: int64

# %%
df_nuevo[df_nuevo['victima_tr_edad'] == 'No corresponde']
# Out:
#        id_hecho  provincia_id provincia_nombre  localidad_id  \
# 1         11535            58          Neuquén           100
# 4         11536            58          Neuquén            40
# 5         11536            58          Neuquén            40
# 8         11537            58          Neuquén            70
# 9         11538            58          Neuquén            10
# ...         ...           ...              ...           ...
# 38117     37757            62        Río Negro            60
# 38119     37758            62        Río Negro            30
# 38121     37759            62        Río Negro            80
# 38122     37796            82         Santa Fe           170
# 38124     34739            54         Misiones            10
#
#               localidad_nombre  anio  mes fecha_hecho hora_hecho  \
# 1                     Plottier  2017    1  2017-01-14   22:38:00
# 4                    Cutral Có  2017    1  2017-01-07   10:35:00
# ...

# %%
df_nuevo[df_nuevo['victima_tr_edad'] == 'Sin determinar']
# Out:
#        id_hecho  provincia_id provincia_nombre  localidad_id  \
# 58        11578            66            Salta            70
# 66        11584            26           Chubut            40
# 400       11779            66            Salta            10
# 576       11921            58          Neuquén            10
# 892       12191            82         Santa Fe            30
# ...         ...           ...              ...           ...
# 37736     37537             6     Buenos Aires            10
# 37849     37593             6     Buenos Aires            10
# 37853     37595             6     Buenos Aires            10
# 38038     37719             6     Buenos Aires            10
# 38067     37731             6     Buenos Aires            10
#
#                              localidad_nombre  anio  mes fecha_hecho  \
# 58     San Ramón de la Nueva Orán (Est. Orán)  2017    1  2017-01-25
# 66                                     Trelew  2017    2  2017-02-24
# ...

# %%
df_nuevo['victima_tr_edad'] = df_nuevo['victima_tr_edad'].replace('No corresponde', 'Sin determinar')

# %%
df_nuevo['victima_tr_edad'].value_counts()
# Out:
# victima_tr_edad
# Sin determinar    19764
# 20-24              2661
# 25-29              2512
# 30-34              2333
# 15-19              1801
# 35-39              1599
# 40-44              1317
# 45-49               958
# 50-54               724
# 55-59               603
# 60-64               474
# 65-69               408
# 70-74               324
# 4 o menos           245
# 75-79               233
# 10-14               187
# 80-84               176
# 5-9                  88
# 85-89                82
# 90 y más             40
# Name: count, dtype: int64

# %% [markdown]
# ### Tratamos 'inculpado_18_años_o_mas'

# %%
# renombramos la columna del inculpado
df_nuevo = df_nuevo.rename(columns={'inculpado_18_años_o_mas':'inculpado_18_anios_o_mas'})

# %%
# unificamos la categoría 'Si' y reemplazamos 'No corresponde'
df_nuevo['inculpado_18_anios_o_mas'] = df_nuevo['inculpado_18_anios_o_mas'].replace('Sí', 'Si')
df_nuevo['inculpado_18_anios_o_mas'] = df_nuevo['inculpado_18_anios_o_mas'].replace('No corresponde', 'Sin determinar')

# %% [markdown]
# ### Tratamos 'inculpado_tr_edad'

# %%
# reemplazamos 'No corresponde' en el tramo de edad del inculpado
df_nuevo['inculpado_tr_edad'] = df_nuevo['inculpado_tr_edad'].replace('No corresponde', 'Sin determinar')

# %%
df_nuevo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36529 entries, 0 to 38125
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   id_hecho                         36529 non-null  int64
#  1   provincia_id                     36529 non-null  int64
#  2   provincia_nombre                 36529 non-null  object
#  3   localidad_id                     36523 non-null  Int64
#  4   localidad_nombre                 36529 non-null  object
#  5   anio                             36529 non-null  int64
#  6   mes                              36529 non-null  int64
#  7   fecha_hecho                      36529 non-null  datetime64[ns]
#  8   hora_hecho                       36529 non-null  object
#  9   tipo_lugar                       36529 non-null  object
#  10  tipo_lugar_otro                  36529 non-null  object
#  11  tipo_lugar_ampliado              36529 non-null  object
# ...

# %%
df_nuevo.to_csv('homicidios_limpio.csv', index=False, sep=';', encoding='utf-8')
